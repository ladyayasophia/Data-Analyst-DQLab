# %% [markdown]
# # [Fungsi Skalar Matematika - ABS()](https://academy.dqlab.id/main/livecode/171/336/1606?pr=0)

# %%
SELECT StudentID, FirstName, LastName, Semester1, Semester2, ABS(MarkGrowth) AS MarkGrowth
FROM students;

# %% [markdown]
# # [Fungsi Skalar Matematika - CEILING()](https://academy.dqlab.id/main/livecode/171/336/1607?pr=0)

# %%
SELECT StudentID, FirstName, LastName, CEILING(Semester1) AS Semester1, CEILING(Semester2) AS Semester2,MarkGrowth
FROM students;

# %% [markdown]
# # [Fungsi Skalar Matematika - FLOOR()](https://academy.dqlab.id/main/livecode/171/336/1608?pr=0)

# %%
SELECT StudentID, FirstName, LastName, FLOOR(Semester1) AS Semester1, FLOOR(Semester2) AS Semester2, MarkGrowth
FROM students;

# %% [markdown]
# # [Fungsi Skalar Matematika - ROUND()](https://academy.dqlab.id/main/livecode/171/336/1609?pr=0)

# %%
SELECT StudentID, FirstName, LastName, ROUND(Semester1,1) AS Semester1, ROUND(Semester2,0) AS Semester2, MarkGrowth
FROM students;

# %% [markdown]
# # [Fungsi Skalar Matematika - SQRT( )](https://academy.dqlab.id/main/livecode/171/336/1610?pr=0)

# %%
SELECT StudentID, FirstName, LastName, SQRT(Semester1) AS Semester1, Semester2, MarkGrowth
FROM students;

# %% [markdown]
# # [Tugas Praktek-1.1](https://academy.dqlab.id/main/livecode/171/336/1611?pr=0)

# %%
SELECT StudentID, FirstName, LastName, MOD(Semester1,2) AS Semester1 , Semester2, EXP(MarkGrowth) FROM students;

# %% [markdown]
# # [Fungsi Text - CONCAT( )](https://academy.dqlab.id/main/livecode/171/337/1613?pr=0)

# %%
SELECT StudentID, CONCAT(FirstName, LastName) AS Name, Semester1, Semester2, MarkGrowth  
FROM students;

# %% [markdown]
# # [Fungsi Text - SUBSTRING_INDEX( )](https://academy.dqlab.id/main/livecode/171/337/1634?pr=0)

# %%
SELECT StudentID, SUBSTRING_INDEX(Email, '@', 1) AS Name
FROM students;

# %% [markdown]
# # [Fungsi Text - SUBSTR( )](https://academy.dqlab.id/main/livecode/171/337/1635?pr=0)

# %%
SELECT StudentID, SUBSTR(FirstName, 2, 3) AS Initial 
FROM students;

# %% [markdown]
# # [Fungsi Text - LENGTH( )](https://academy.dqlab.id/main/livecode/171/337/1636?pr=0)

# %%
SELECT StudentID, FirstName, LENGTH(FirstName) AS Total_Char
FROM students;

# %% [markdown]
# # [Fungsi Text - REPLACE( )](https://academy.dqlab.id/main/livecode/171/337/1637?pr=0)

# %%
SELECT StudentID, Email, REPLACE(Email,'yahoo', 'gmail') AS New_Email
FROM students;

# %% [markdown]
# # [Tugas Praktek-2.1](https://academy.dqlab.id/main/livecode/171/337/1638?pr=0)

# %%
SELECT StudentID, UPPER(FirstName) AS FirstName, LOWER(LastName) AS LastName FROM students;

# %% [markdown]
# # [Fungsi Aggregate - SUM()](https://academy.dqlab.id/main/livecode/171/340/1640?pr=null)

# %%
SELECT SUM(Semester1) AS Total_1, SUM(Semester2) AS Total_2
FROM students;

# %% [markdown]
# # [Fungsi Aggregate - COUNT()](https://academy.dqlab.id/main/livecode/171/340/1641?pr=null)

# %%
SELECT COUNT(FirstName) AS Total_Student 
FROM students;

# %% [markdown]
# # [Fungsi Aggregate - AVG( )](https://academy.dqlab.id/main/livecode/171/340/1642?pr=null)

# %%
SELECT AVG(Semester1) AS AVG_1, AVG(Semester2) AS AVG_2 
FROM students;

# %% [markdown]
# # [Tugas Praktek-3.1](https://academy.dqlab.id/main/livecode/171/340/1643?pr=null)

# %%
SELECT MIN(Semester1) AS Min1, MAX(Semester1) AS Max1,MIN(Semester2) AS Min2, MAX(Semester2) AS Max2
FROM students;

# %% [markdown]
# # [Group by Single Column](https://academy.dqlab.id/main/livecode/171/340/1645?pr=null)

# %%
SELECT province,
COUNT(DISTINCT order_id) AS total_order,
SUM(item_price) AS total_price
FROM sales_retail_2019
GROUP BY province;

# %% [markdown]
# # [Group by Multiple Column](https://academy.dqlab.id/main/livecode/171/340/1646?pr=null)

# %%
SELECT province,brand,
COUNT(DISTINCT order_id) AS total_order,
SUM(Item_price) AS total_price FROM sales_retail_2019
GROUP BY province, brand;

# %% [markdown]
# # [Fungsi Aggregate dengan Grouping](https://academy.dqlab.id/main/livecode/171/340/1647?pr=null)

# %%
SELECT province, 
COUNT(DISTINCT order_id) AS total_unique_order,
SUM(item_price) AS revenue 
FROM sales_retail_2019
GROUP BY province;

# %% [markdown]
# # [Tugas Praktek-3.2](https://academy.dqlab.id/main/livecode/171/340/1650?pr=null)

# %%
SELECT MONTH(order_date) AS order_month, SUM(item_price) AS total_price, 
CASE  
    WHEN SUM(item_price) >= 30000000000 THEN 'Target Achieved'
    WHEN SUM(item_price) <= 25000000000 THEN 'Less Performed'
    ELSE 'Follow Up'
END as remark
FROM sales_retail_2019
GROUP BY MONTH(order_date);

# %% [markdown]
# # [Proyek Pekerjaan - Analisis Penjualan Part 1](https://academy.dqlab.id/main/livecode/171/341/1652?pr=null)

# %%
-- 1. Total jumlah seluruh penjualan (total/revenue).
SELECT SUM(total) as total 
FROM tr_penjualan;
-- 2. Total quantity seluruh produk yang terjual.
SELECT SUM(qty) as qty 
FROM tr_penjualan;
-- 3. Total quantity dan total revenue untuk setiap kode produk.
SELECT kode_produk, SUM(qty) as qty, SUM(total) as total 
FROM tr_penjualan
GROUP BY kode_produk;

# %% [markdown]
# # [Proyek Pekerjaan - Analisis Penjualan Part 2](https://academy.dqlab.id/main/livecode/171/341/1654?pr=null)

# %%
-- 4. Rata - Rata total belanja per kode pelanggan.
SELECT kode_pelanggan, AVG(total) AS avg_total 
FROM tr_penjualan
GROUP BY kode_pelanggan;
/* 5. Selain itu,  jangan lupa untuk menambahkan kolom baru 
dengan nama ‘kategori’ yang mengkategorikan total/revenue ke dalam 
3 kategori: High: > 300K; Medium: 100K - 300K; Low: <100K. */
SELECT kode_transaksi,kode_pelanggan,no_urut,kode_produk,nama_produk,qty,total,
CASE  
    WHEN total > 300000 THEN 'High'
    WHEN total < 100000 THEN 'Low'   
    ELSE 'Medium'  
END as kategori 
FROM tr_penjualan;
